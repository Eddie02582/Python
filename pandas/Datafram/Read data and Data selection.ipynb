# %% [markdown]
# ## Read data

# %% [markdown]
# <ul>
#     <li>read csv</li>
#     <li>read html</li>
#     <li>read excel</li>
# </ul>

# %% [markdown]
# ### read csv

# %%
import pandas as pd

# %%
path = "data.csv"

# %%
#read data from csv
df = pd.read_csv(path)

# %%
df
# Out:
#      #                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA  \
# 0    1             James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6
# 1    2             Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4
# 2    3    Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8
# 3    4               Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5
# 4    5           Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9
# 5    6              Luka Doncic  54  33.3  28.7   9.5  20.6  46.1  2.9   9.1
# 6    7        Russell Westbrook  53  35.9  27.5  10.7  22.6  47.4  1.0   3.8
# 7    8            Kawhi Leonard  51  32.2  26.9   9.3  19.9  46.9  2.1   5.7
# 8    9            Anthony Davis  55  34.3  26.7   9.2  18.1  51.1  1.2   3.5
# 9   10             Devin Booker  62  36.1  26.1   8.8  18.0  48.7  2.0   5.6
# 10  11             LeBron James  60  34.9  25.7   9.8  19.6  49.8  2.2   6.4
# ...

# %% [markdown]
# ## ExcelFile

# %%
path = "data.xls"

# %%
workbook = pd.ExcelFile(path)

# %%
sheetname = workbook.sheet_names[0]

# %%
df = workbook.parse(sheetname,header = 0)

# %%
df
# Out:
#                      Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA  \
# 0              James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6
# 1              Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4
# 2     Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8
# 3                Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5
# 4            Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9
# 5               Luka Doncic  54  33.3  28.7   9.5  20.6  46.1  2.9   9.1
# 6         Russell Westbrook  53  35.9  27.5  10.7  22.6  47.4  1.0   3.8
# 7             Kawhi Leonard  51  32.2  26.9   9.3  19.9  46.9  2.1   5.7
# 8             Anthony Davis  55  34.3  26.7   9.2  18.1  51.1  1.2   3.5
# 9              Devin Booker  62  36.1  26.1   8.8  18.0  48.7  2.0   5.6
# 10             LeBron James  60  34.9  25.7   9.8  19.6  49.8  2.2   6.4
# 11              Zach LaVine  60  34.8  25.5   9.0  20.0  45.0  3.1   8.1
# ...

# %% [markdown]
# ### read_excel

# %%
df = pd.read_excel("data.xls")
#pd.read_excel("data.xls",sheet_name = 0)
#df = pd.read_excel("data.xls",sheet_name = "Sheet1")

# %% [markdown]
# ## Data Selection

# %% [markdown]
# ### row data

# %% [markdown]
# #### DataFrame.head(n)

# %% [markdown]
# 取出前幾項(default n = 5)

# %%
df.head()
# Out:
#                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6  35.2
# 1           Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4  35.3
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8  30.6
# 3             Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5  36.1
# 4         Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9  39.4
#
#    ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...  11.8  86.1   1.0   5.3   6.4  7.4  1.7  0.9  4.5  31.8
# 1  ...   8.0  84.2   0.9   3.3   4.2  6.1  1.2  0.4  3.4  25.4
# 2  ...  10.0  63.3   2.3  11.5  13.7  5.8  1.0  1.0  3.7  34.8
# 3  ...   9.3  86.0   0.5   3.7   4.3  9.3  1.1  0.1  4.8  26.6
# 4  ...   7.6  88.8   0.5   3.8   4.3  7.8  1.0  0.4  2.9  27.8
#
# [5 rows x 21 columns]

# %%
#equal df[:3]
df.head(3)
# Out:
#                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6  35.2
# 1           Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4  35.3
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8  30.6
#
#    ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...  11.8  86.1   1.0   5.3   6.4  7.4  1.7  0.9  4.5  31.8
# 1  ...   8.0  84.2   0.9   3.3   4.2  6.1  1.2  0.4  3.4  25.4
# 2  ...  10.0  63.3   2.3  11.5  13.7  5.8  1.0  1.0  3.7  34.8
#
# [3 rows x 21 columns]

# %% [markdown]
# #### DataFrame.tail(n)

# %% [markdown]
# 取出後n項(default n = 5)

# %%
#get last five items
df.tail()
# Out:
#               Player  GP   MIN   PTS  FGM   FGA   FG%  3PM  3PA   3P%  ...  \
# 45  Montrezl Harrell  63  27.8  18.6  7.5  12.9  58.0  0.0  0.3   0.0  ...
# 46  Domantas Sabonis  62  34.8  18.5  7.4  13.7  54.0  0.3  1.1  25.4  ...
# 47   Devonte' Graham  63  35.1  18.2  5.8  15.3  38.2  3.5  9.3  37.3  ...
# 48      Derrick Rose  50  26.0  18.1  7.4  15.1  49.0  0.9  2.9  30.6  ...
# 49      Terry Rozier  63  34.4  18.0  6.3  14.9  42.3  2.7  6.7  40.7  ...
#
#     FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 45  5.6  65.8   2.6   4.5   7.1  1.7  0.6  1.1  1.7  20.1
# 46  4.8  72.3   3.0   9.4  12.4  5.0  0.8  0.5  2.7  26.8
# 47  3.7  82.0   0.7   2.7   3.4  7.5  1.0  0.2  2.9  17.3
# 48  2.8  87.1   0.5   1.9   2.4  5.6  0.8  0.3  2.5  16.6
# 49  3.0  87.4   0.8   3.6   4.4  4.1  1.0  0.2  2.2  16.4
#
# [5 rows x 21 columns]

# %% [markdown]
# #### df

# %%
# use df 
df[:5]
# Out:
#                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6  35.2
# 1           Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4  35.3
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8  30.6
# 3             Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5  36.1
# 4         Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9  39.4
#
#    ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...  11.8  86.1   1.0   5.3   6.4  7.4  1.7  0.9  4.5  31.8
# 1  ...   8.0  84.2   0.9   3.3   4.2  6.1  1.2  0.4  3.4  25.4
# 2  ...  10.0  63.3   2.3  11.5  13.7  5.8  1.0  1.0  3.7  34.8
# 3  ...   9.3  86.0   0.5   3.7   4.3  9.3  1.1  0.1  4.8  26.6
# 4  ...   7.6  88.8   0.5   3.8   4.3  7.8  1.0  0.4  2.9  27.8
#
# [5 rows x 21 columns]

# %% [markdown]
# #### df.iloc

# %% [markdown]
# 用法為 df.iloc[[row_indexs]]好處是可以指定row

# %%
df.iloc[:5]
# Out:
#                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6  35.2
# 1           Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4  35.3
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8  30.6
# 3             Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5  36.1
# 4         Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9  39.4
#
#    ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...  11.8  86.1   1.0   5.3   6.4  7.4  1.7  0.9  4.5  31.8
# 1  ...   8.0  84.2   0.9   3.3   4.2  6.1  1.2  0.4  3.4  25.4
# 2  ...  10.0  63.3   2.3  11.5  13.7  5.8  1.0  1.0  3.7  34.8
# 3  ...   9.3  86.0   0.5   3.7   4.3  9.3  1.1  0.1  4.8  26.6
# 4  ...   7.6  88.8   0.5   3.8   4.3  7.8  1.0  0.4  2.9  27.8
#
# [5 rows x 21 columns]

# %%
df.iloc[[1,3,4]]
# Out:
#            Player  GP   MIN   PTS   FGM   FGA   FG%  3PM  3PA   3P%  ...  FTA  \
# 1    Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0  8.4  35.3  ...  8.0
# 3      Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4  9.5  36.1  ...  9.3
# 4  Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9  9.9  39.4  ...  7.6
#
#     FT%  OREB  DREB  REB  AST  STL  BLK  TOV   EFF
# 1  84.2   0.9   3.3  4.2  6.1  1.2  0.4  3.4  25.4
# 3  86.0   0.5   3.7  4.3  9.3  1.1  0.1  4.8  26.6
# 4  88.8   0.5   3.8  4.3  7.8  1.0  0.4  2.9  27.8
#
# [3 rows x 21 columns]

# %%
df.iloc[0]
# Out:
# Player    James Harden
# GP                  61
# MIN               36.7
# PTS               34.4
# FGM                9.9
# FGA               22.7
# FG%               43.5
# 3PM                4.4
# 3PA               12.6
# 3P%               35.2
# FTM               10.1
# FTA               11.8
# FT%               86.1
# OREB                 1
# DREB               5.3
# REB                6.4
# AST                7.4
# STL                1.7
# BLK                0.9
# TOV                4.5
# EFF               31.8
# Name: 0, dtype: object

# %% [markdown]
# #### df.loc

# %% [markdown]
# 與iloc差別在取col是以欄位名稱

# %%
df.loc[0:5]
# Out:
#                   Player  GP   MIN   PTS   FGM   FGA   FG%  3PM   3PA   3P%  \
# 0           James Harden  61  36.7  34.4   9.9  22.7  43.5  4.4  12.6  35.2
# 1           Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0   8.4  35.3
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9  20.0  54.7  1.5   4.8  30.6
# 3             Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4   9.5  36.1
# 4         Damian Lillard  58  36.9  28.9   9.2  20.0  45.7  3.9   9.9  39.4
# 5            Luka Doncic  54  33.3  28.7   9.5  20.6  46.1  2.9   9.1  31.8
#
#    ...   FTA   FT%  OREB  DREB   REB  AST  STL  BLK  TOV   EFF
# 0  ...  11.8  86.1   1.0   5.3   6.4  7.4  1.7  0.9  4.5  31.8
# 1  ...   8.0  84.2   0.9   3.3   4.2  6.1  1.2  0.4  3.4  25.4
# 2  ...  10.0  63.3   2.3  11.5  13.7  5.8  1.0  1.0  3.7  34.8
# 3  ...   9.3  86.0   0.5   3.7   4.3  9.3  1.1  0.1  4.8  26.6
# 4  ...   7.6  88.8   0.5   3.8   4.3  7.8  1.0  0.4  2.9  27.8
# ...

# %%
df.loc[[1,3,5]]
# Out:
#          Player  GP   MIN   PTS   FGM   FGA   FG%  3PM  3PA   3P%  ...  FTA  \
# 1  Bradley Beal  57  36.0  30.5  10.4  22.9  45.5  3.0  8.4  35.3  ...  8.0
# 3    Trae Young  60  35.3  29.6   9.1  20.8  43.7  3.4  9.5  36.1  ...  9.3
# 5   Luka Doncic  54  33.3  28.7   9.5  20.6  46.1  2.9  9.1  31.8  ...  9.1
#
#     FT%  OREB  DREB  REB  AST  STL  BLK  TOV   EFF
# 1  84.2   0.9   3.3  4.2  6.1  1.2  0.4  3.4  25.4
# 3  86.0   0.5   3.7  4.3  9.3  1.1  0.1  4.8  26.6
# 5  75.2   1.3   8.0  9.3  8.7  1.1  0.2  4.2  30.4
#
# [3 rows x 21 columns]

# %%
df.loc[0]
# Out:
# Player    James Harden
# GP                  61
# MIN               36.7
# PTS               34.4
# FGM                9.9
# FGA               22.7
# FG%               43.5
# 3PM                4.4
# 3PA               12.6
# 3P%               35.2
# FTM               10.1
# FTA               11.8
# FT%               86.1
# OREB                 1
# DREB               5.3
# REB                6.4
# AST                7.4
# STL                1.7
# BLK                0.9
# TOV                4.5
# EFF               31.8
# Name: 0, dtype: object

# %% [markdown]
# ### col data and row data

# %% [markdown]
# #### df

# %%
df [['Player','PTS','EFF']][:5]
# Out:
#                   Player   PTS   EFF
# 0           James Harden  34.4  31.8
# 1           Bradley Beal  30.5  25.4
# 2  Giannis Antetokounmpo  29.6  34.8
# 3             Trae Young  29.6  26.6
# 4         Damian Lillard  28.9  27.8

# %% [markdown]
# #### iloc

# %% [markdown]
# 指定index
# df.iloc[[row_indexs],[col_indexs]]

# %% [markdown]
# 使用切片
# df.iloc[r1:r2,c1:c2]

# %%
#df.iloc 切片
df.iloc[:2,0:5]
# Out:
#          Player  GP   MIN   PTS   FGM
# 0  James Harden  61  36.7  34.4   9.9
# 1  Bradley Beal  57  36.0  30.5  10.4

# %%
# df.iloc[[row_indexs],[col_indexs]]
df.iloc[[1,2],[1,2,5]]
# Out:
#    GP   MIN   FGA
# 1  57  36.0  22.9
# 2  57  30.9  20.0

# %%
#combine slice and df.iloc[[row_indexs],]
df.iloc[[1,3,5],0:5]
# Out:
#          Player  GP   MIN   PTS   FGM
# 1  Bradley Beal  57  36.0  30.5  10.4
# 3    Trae Young  60  35.3  29.6   9.1
# 5   Luka Doncic  54  33.3  28.7   9.5

# %%
#combine slice and df.iloc[r1:r2,[col_indexs],]
df.iloc[:2,[1,2,5]]
# Out:
#    GP   MIN   FGA
# 0  61  36.7  22.7
# 1  57  36.0  22.9

# %% [markdown]
# #### df.loc

# %% [markdown]
# df.loc[[row_index],[colname]]

# %%
df.loc[[1,3,5],['Player','GP','MIN','EFF','PTS']]
# Out:
#          Player  GP   MIN   EFF   PTS
# 1  Bradley Beal  57  36.0  25.4  30.5
# 3    Trae Young  60  35.3  26.6  29.6
# 5   Luka Doncic  54  33.3  30.4  28.7

# %%
#df.iloc 切片
df.loc[:2,df.columns[0:5]]
# Out:
#                   Player  GP   MIN   PTS   FGM
# 0           James Harden  61  36.7  34.4   9.9
# 1           Bradley Beal  57  36.0  30.5  10.4
# 2  Giannis Antetokounmpo  57  30.9  29.6  10.9

# %%
#df.iloc 切片
df.loc[:2,['Player','GP','MIN','EFF','PTS']]
# Out:
#                   Player  GP   MIN   EFF   PTS
# 0           James Harden  61  36.7  31.8  34.4
# 1           Bradley Beal  57  36.0  25.4  30.5
# 2  Giannis Antetokounmpo  57  30.9  34.8  29.6

# %%
df.loc[0][1]
# Out:
# 61
